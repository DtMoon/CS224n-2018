# %%
# with the following two lines of code, modules will be auto-reloaded by default
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## 1 A window into NER

# %%
# !python q1_window.py test1
# Out:
# /home/lanhongyuee/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:Testing make_windowed_data
# INFO:Passed!

# %%
# !python q1_window.py test2
# Out:
# /home/lanhongyuee/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:Testing implementation of WindowModel
# INFO:Loading training data...
# INFO:Done. Read 721 sentences
# INFO:Loading dev data...
# INFO:Done. Read 721 sentences
# INFO:Built dictionary for 2653 features.
# INFO:Initialized embeddings.
# INFO:Building model...
# INFO:took 3.04 seconds
# 2018-09-25 18:08:04.094960: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# ...

# %%
# !python q1_window.py train
# Out:
# /home/lanhongyuee/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:Loading training data...
# INFO:Done. Read 14041 sentences
# INFO:Loading dev data...
# INFO:Done. Read 3250 sentences
# INFO:Built dictionary for 10007 features.
# INFO:The first training example:
# (['EU', 'rejects', 'German', 'call', 'to', 'boycott', 'British', 'lamb', '.'], ['ORG', 'O', 'MISC', 'O', 'O', 'O', 'MISC', 'O', 'O'])
# INFO:The first preprocessed training example:
# ([[924, 10001], [10006, 10000], [186, 10002], [578, 10000], [7, 10000], [3800, 10000], [196, 10002], [5580, 10000], [3, 10003]], [1, 4, 3, 4, 4, 4, 3, 4, 4])
# INFO:Initialized embeddings.
# INFO:Building model...
# INFO:took 3.10 seconds
# ...

# %%
# !python q1_window.py shell -m results/window/20180925_180810/
# Out:
# /home/lanhongyuee/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:Initialized embeddings.
# INFO:Building model...
# INFO:took 3.14 seconds
# 2018-09-25 18:40:51.025759: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2018-09-25 18:40:51.027433: I tensorflow/core/common_runtime/process_util.cc:69] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# INFO:tensorflow:Restoring parameters from results/window/20180925_180810/model.weights
# INFO:Restoring parameters from results/window/20180925_180810/model.weights
# Welcome!
# ...

# %% [markdown]
# ## 2 Recurrent neural nets for NER

# %%
# !python q2_rnn_cell.py test
# Out:
# /home/lanhongyuee/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:Testing rnn_cell
# 2018-09-25 19:51:03.962684: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2018-09-25 19:51:03.964390: I tensorflow/core/common_runtime/process_util.cc:69] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# y_ = [[0.8320184  0.880797  ]
#  [0.7310586  0.62245935]]
# ht_ = [[0.8320184  0.880797  ]
#  [0.7310586  0.62245935]]
# INFO:Passed!

# %%
# !python q2_rnn.py test1
# Out:
# /home/lanhongyuee/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:Testing pad_sequences
# INFO:Passed!

# %%
a = [[1,9], [2,9], [3,8], [4,8]]

# %%
d = []
# i is the reference to each element of a
for i in a:
    d.append(i)

# %%
d[0][0] = -1

# %%
d
# Out:
# [[-1, 9], [2, 9], [3, 8], [4, 8]]

# %%
a
# Out:
# [[-1, 9], [2, 9], [3, 8], [4, 8]]

# %%
b = a[:2]

# %%
b
# Out:
# [[-1, 9], [2, 9]]

# %%
a
# Out:
# [[-1, 9], [2, 9], [3, 8], [4, 8]]

# %%
b[0][0] = 10

# %%
b
# Out:
# [[10, 9], [2, 9]]

# %%
a
# Out:
# [[10, 9], [2, 9], [3, 8], [4, 8]]

# %% [markdown]
# **Note:**
#
# Evaluating on development data is **slow** because we need to ues tf.argmax() to get the prediction.

# %%
# !python q2_rnn.py test2
# Out:
# /home/lanhongyuee/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:Testing implementation of RNNModel
# INFO:Loading training data...
# INFO:Done. Read 721 sentences
# INFO:Loading dev data...
# INFO:Done. Read 721 sentences
# INFO:Built dictionary for 2653 features.
# INFO:Initialized embeddings.
# INFO:Building model...
# /home/lanhongyuee/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:100: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# INFO:took 7.64 seconds
# ...

# %%
# !python q2_rnn.py train
# Out:
# /home/lanhongyuee/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:Loading training data...
# INFO:Done. Read 14041 sentences
# INFO:Loading dev data...
# INFO:Done. Read 3250 sentences
# INFO:Built dictionary for 10007 features.
# INFO:Initialized embeddings.
# INFO:Building model...
# /home/lanhongyuee/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:100: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# INFO:took 10.98 seconds
# ...

# %% [markdown]
# ## 3 Grooving with GRUs

# %%
# !python q3_gru_cell.py test
# Out:
# /home/lanhongyuee/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:Testing gru_cell
# 2018-09-26 15:42:55.605920: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2018-09-26 15:42:55.607691: I tensorflow/core/common_runtime/process_util.cc:69] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# y_ = [[ 0.32035077  0.55478156]
#  [-0.00592546  0.0195577 ]]
# ht_ = [[ 0.32035077  0.55478156]
#  [-0.00592546  0.0195577 ]]
# INFO:Passed!

# %%
# !python q3_gru.py predict -c rnn
# Out:
# /home/lanhongyuee/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# q3_gru.py:28: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "q3_gru.py", line 20, in <module>
#     import matplotlib.pyplot as plt
#   File "/home/lanhongyuee/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py", line 71, in <module>
#     from matplotlib.backends import pylab_setup
# ...

# %%
# !python q3_gru.py predict -c gru
# Out:
# /home/lanhongyuee/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# q3_gru.py:28: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "q3_gru.py", line 20, in <module>
#     import matplotlib.pyplot as plt
#   File "/home/lanhongyuee/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py", line 71, in <module>
#     from matplotlib.backends import pylab_setup
# ...

# %%
# !python q3_gru.py predict -c rnn -g
# Out:
# /home/lanhongyuee/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# q3_gru.py:28: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "q3_gru.py", line 20, in <module>
#     import matplotlib.pyplot as plt
#   File "/home/lanhongyuee/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py", line 71, in <module>
#     from matplotlib.backends import pylab_setup
# ...

# %%
# !python q3_gru.py predict -c gru -g
# Out:
# /home/lanhongyuee/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# q3_gru.py:28: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "q3_gru.py", line 20, in <module>
#     import matplotlib.pyplot as plt
#   File "/home/lanhongyuee/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py", line 71, in <module>
#     from matplotlib.backends import pylab_setup
# ...

# %% [markdown]
# <table>
# <td>
# <img src="q3-clip-rnn.png" style="width:400;height:400px;">
# <td>
#
# <td>
# <img src="q3-noclip-rnn.png" style="width:400;height:400px;">
# <td>
# </table>
#
# <table>
# <td>
# <img src="q3-clip-gru.png" style="width:400;height:400px;">
# <td>
#
# <td>
# <img src="q3-noclip-gru.png" style="width:400;height:400px;">
# <td>
# </table>

# %%
# !python q2_rnn.py train -c gru
# Out:
# /home/lanhongyuee/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:Loading training data...
# INFO:Done. Read 14041 sentences
# INFO:Loading dev data...
# INFO:Done. Read 3250 sentences
# INFO:Built dictionary for 10007 features.
# INFO:Initialized embeddings.
# INFO:Building model...
# /home/lanhongyuee/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:100: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# INFO:took 22.38 seconds
# ...

# %% [markdown]
# ## 4 LSTM

# %%
# !python q2_rnn.py train -c lstm
# Out:
# /home/lanhongyuee/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:Loading training data...
# INFO:Done. Read 14041 sentences
# INFO:Loading dev data...
# INFO:Done. Read 3250 sentences
# INFO:Built dictionary for 10007 features.
# INFO:Initialized embeddings.
# INFO:Building model...
# /home/lanhongyuee/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:100: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# INFO:took 25.30 seconds
# ...
